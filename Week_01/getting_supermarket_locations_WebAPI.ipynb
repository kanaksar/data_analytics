# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# (3464, 277)
#    type        id        lat       lon tags.addr:city tags.addr:country  \
# 0  node  33126515  47.155616  9.037915        Schänis                CH
# 1  node  36726161  47.226191  8.980329         Uznach               NaN
# 2  node  39768209  47.225154  8.969868         Uznach               NaN
# 3  node  39947904  47.376732  8.542161         Zürich                CH
# 4  node  48932835  47.375020  8.522895         Zürich               NaN
#
#   tags.addr:housenumber tags.addr:postcode tags.addr:street tags.brand  ...  \
# 0                    32               8718   Biltnerstrasse       Spar  ...
# 1                    25               8730   Zürcherstrasse     Migros  ...
# 2                   NaN               8730              NaN       Coop  ...
# 3                     1               8001    Bahnhofbrücke       Coop  ...
# 4                     7               8004     Wengistrasse     Migros  ...
#
#   tags.source:addr tags.opening_date tags.postid tags.payment:account_cards  \
# 0              NaN               NaN         NaN                        NaN
# 1              NaN               NaN         NaN                        NaN
# 2              NaN               NaN         NaN                        NaN
# 3              NaN               NaN         NaN                        NaN
# 4              NaN               NaN         NaN                        NaN
#
#   tags.diet:mediterranean tags.diet:seafood tags.recycling:low_energy_bulbs  \
# 0                     NaN               NaN                             NaN
# 1                     NaN               NaN                             NaN
# 2                     NaN               NaN                             NaN
# 3                     NaN               NaN                             NaN
# 4                     NaN               NaN                             NaN
#
#   tags.opening_hours:cafe tags.name:zh-Hans tags.panoramax
# 0                     NaN               NaN            NaN
# 1                     NaN               NaN            NaN
# 2                     NaN               NaN            NaN
# 3                     NaN               NaN            NaN
# 4                     NaN               NaN            NaN
#
# [5 rows x 277 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 6  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a9a78917fcbf645a256a536a26c4468 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a9a78917fcbf645a256a536a26c4468&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a9a78917fcbf645a256a536a26c4468 = L.map(
#                 &quot;map_2a9a78917fcbf645a256a536a26c4468&quot;,
#                 {
#                     center: [47.009806057743, 8.006914463920923],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2a9a78917fcbf645a256a536a26c4468);
#
#
#
#
#
#             var tile_layer_5178fee99b6b9ca188d8437bc1872a0c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5178fee99b6b9ca188d8437bc1872a0c.addTo(map_2a9a78917fcbf645a256a536a26c4468);
#
#
#             var marker_a14c5f61e612ffad613c523c1b9907fa = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_2a9a78917fcbf645a256a536a26c4468);
#
#
#         var popup_b3d35e63c44963fc13aa2312f224c9ce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_654b77c847a4a86a2ca598a2037b608b = $(`&lt;div id=&quot;html_654b77c847a4a86a2ca598a2037b608b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_b3d35e63c44963fc13aa2312f224c9ce.setContent(html_654b77c847a4a86a2ca598a2037b608b);
#
#
#
#         marker_a14c5f61e612ffad613c523c1b9907fa.bindPopup(popup_b3d35e63c44963fc13aa2312f224c9ce)
#         ;
#
#
#
#
#             var marker_bcc6b43ea178c4ad44423269e274fccc = L.marker(
#                 [47.2251539, 8.9698681],
#                 {}
#             ).addTo(map_2a9a78917fcbf645a256a536a26c4468);
#
#
#         var popup_6791fee9122488b64cd05e3f2494a138 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_859ce8f25380d52c1a641e5b842372e4 = $(`&lt;div id=&quot;html_859ce8f25380d52c1a641e5b842372e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_6791fee9122488b64cd05e3f2494a138.setContent(html_859ce8f25380d52c1a641e5b842372e4);
#
#
#
#         marker_bcc6b43ea178c4ad44423269e274fccc.bindPopup(popup_6791fee9122488b64cd05e3f2494a138)
#         ;
#
#
#
#
#             var marker_8e217e9ac20e71d3775ff23367e0a006 = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_2a9a78917fcbf645a256a536a26c4468);
#
#
#         var popup_ae27933193d55e11504a93b14a94c0e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0bf461409ff018a9fb830bbbe04a985c = $(`&lt;div id=&quot;html_0bf461409ff018a9fb830bbbe04a985c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_ae27933193d55e11504a93b14a94c0e5.setContent(html_0bf461409ff018a9fb830bbbe04a985c);
#
#
#
#         marker_8e217e9ac20e71d3775ff23367e0a006.bindPopup(popup_ae27933193d55e11504a93b14a94c0e5)
#         ;
#
#
#
#
#             var marker_25940a44e00ee7594986de3fd8e68de2 = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_2a9a78917fcbf645a256a536a26c4468);
#
#
#         var popup_52859f29cd611dbe5cdfd706fb6937d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5357f52e8c25e649778ffbf9712becdb = $(`&lt;div id=&quot;html_5357f52e8c25e649778ffbf9712becdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_52859f29cd611dbe5cdfd706fb6937d7.setContent(html_5357f52e8c25e649778ffbf9712becdb);
#
#
#
#         marker_25940a44e00ee7594986de3fd8e68de2.bindPopup(popup_52859f29cd611dbe5cdfd706fb6937d7)
#         ;
#
#
#
#
#             var marker_6623df3ccc555dfaf3918f96a8bde3f0 = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_2a9a78917fcbf645a256a536a26c4468);
#
#
#         var popup_789d9be74d591fb2e4009b70fa7514d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a81f3fa493107d30acd439638dda9887 = $(`&lt;div id=&quot;html_a81f3fa493107d30acd439638dda9887&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_789d9be74d591fb2e4009b70fa7514d7.setContent(html_a81f3fa493107d30acd439638dda9887);
#
#
#
#         marker_6623df3ccc555dfaf3918f96a8bde3f0.bindPopup(popup_789d9be74d591fb2e4009b70fa7514d7)
#         ;
#
#
#
#
#             var marker_9995e9d49f676a60db5ab8b45b683c97 = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1030-azure
# Datetime: 2025-12-07 14:39:24
# Python Version: 3.11.14
# -----------------------------------
